# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# %%
names=[]
ratings=[]
strongfoot=[]
weakfoot=[]
position = []
sidePosition = []
skill_moves = []
pace = []
shooting = []
passing = []
dribbling = []
defending = []
physic = []
popularity = []
igs=[]
body= []
age=[]
weight=[]
price=[]
nation = []
league = []
club = []
service = webdriver.chrome.service.Service("chromedriver.exe")
for page in range(1,10):
    print(f'Page {page}')
    link=f'https://www.futbin.com/players?page={page}&version=all_icons&showStats=Age%2CWeight&gender=men'
    driver = webdriver.Chrome(service=service)
    driver.get(link)
    time.sleep(10)

    tbody_rows=driver.find_elements(By.CLASS_NAME,'player-row')
    for row in tbody_rows:
        names.append(row.find_element(By.CLASS_NAME,'table-player-name').text)
        ratings.append(row.find_element(By.CLASS_NAME,'player-rating-card-text').text)
        position.append(row.find_element(By.CLASS_NAME,'table-pos-main').text)
        print(names[-1])
        try:
            sidePosition.append(row.find_element(By.CLASS_NAME,'table-pos').find_element(By.CLASS_NAME,'text-faded').text)
        except: 
            sidePosition.append(None)
        price.append(row.find_element(By.CLASS_NAME,'price').text)
        weakfoot.append(row.find_element(By.CLASS_NAME,'table-weak-foot').text)
        skill_moves.append(row.find_element(By.CLASS_NAME,'table-skills').text)
        pace.append(row.find_element(By.CLASS_NAME,'table-key-stats').text)
        shooting.append(row.find_element(By.CLASS_NAME,'table-shooting').text)
        passing.append(row.find_element(By.CLASS_NAME,'table-passing').text)
        dribbling.append(row.find_element(By.CLASS_NAME,'table-dribbling').text)
        defending.append(row.find_element(By.CLASS_NAME,'table-defending').text)
        physic.append(row.find_element(By.CLASS_NAME,'table-physicality').text)
        popularity.append(row.find_element(By.CLASS_NAME,'table-popularity').text)
        igs.append(row.find_element(By.CLASS_NAME,'table-in-game-stats').text)
        body.append(row.find_element(By.CLASS_NAME,'table-height').text)
        age.append(row.find_element(By.CLASS_NAME,'table-age').text)
        weight.append(row.find_element(By.CLASS_NAME,'table-weight').text)
        nation.append(row.find_element(By.CLASS_NAME,'table-player-nation').find_element(By.TAG_NAME,'img').get_attribute('title'))
        league.append(row.find_element(By.CLASS_NAME,'table-player-league').find_element(By.TAG_NAME,'img').get_attribute('title'))
        club.append(row.find_element(By.CLASS_NAME,'table-player-club').find_element(By.TAG_NAME,'img').get_attribute('title'))
        player_strongfoot=row.find_element(By.CLASS_NAME,'table-foot').find_element(By.TAG_NAME,'img').get_attribute('src')
        if 'right' in player_strongfoot:
            strongfoot.append('Right')
        else:
            strongfoot.append('Left')
    
    driver.quit()
# Out:
# Page 1
# Edson Arantes Nascimento
# Zinedine Zidane
# Edson Arantes Nascimento
# Johan Cruyff
# Diego Maradona
# Ronaldo Luís Nazário de Lima
# Beckenbauer
# Eusébio da Silva Ferreira
# Franck Ribéry
# Edson Arantes Nascimento
# Ronaldo Luís Nazário de Lima
# Eusébio da Silva Ferreira
# Diego Maradona
# Ronaldo de Assis Moreira
# Thierry Henry
    'Dribbling': dribbling,
    'Defending': defending,
    'Physic': physic,
    'Popularity': popularity,
    'IGS': igs,
    'Body': body,
    'Age': age,
    'Weight': weight,
    'Nation': nation,
    'League': league,
    'Club': club
})
icons
# Out:
#                        Player Rating Strong Foot Position sidePosition  \
# 0    Edson Arantes Nascimento     97       Right    CAM++         ST++
# 1             Zinedine Zidane     96       Right    CAM++           CM
# 2    Edson Arantes Nascimento     96       Right    CAM++         ST++
# 3                Johan Cruyff     96       Right    CAM++           ST
# 4              Diego Maradona     96        Left    CAM++           ST
# ..                        ...    ...         ...      ...          ...
# 255              Sol Campbell     86       Right     CB++         None
# 256           Gennaro Gattuso     86       Right    CDM++           CM
# 257        Gianluca Zambrotta     86       Right     RB++           LB
# 258             Frank Lampard     86       Right     CM++     CDM, CAM
# 259            Diego Maradona     77        Left    CAM++         None
#
#       Price Weak Foot Skill Moves Pace Shooting  ... Defending Physic  \
# 0     6.27M         4           5   95       97  ...        61     82
# 1      999K         5           5   86       92  ...        76     86
# 2        2M         4           5   94       95  ...        60     80
# 3     4.78M         5           5   93       94  ...        45     78
# 4     3.73M         5           5   92       92  ...        42     80
# ..      ...       ...         ...  ...      ...  ...       ...    ...
# 255   65.5K         3           2   81       45  ...        87     88
# 256     66K         3           2   73       62  ...        88     87
# 257     69K         5           4   87       69  ...        84     82
# 258  113.1K         4           4   84       86  ...        80     84
# 259       0         3           4   84       80  ...        34     56
#
#     Popularity   IGS                                               Body Age  \
# 0          226  2553                     173cm | 5'8"\nMostly Explosive  84
# 1          574  2570                   185cm | 6'0'\nControlled Lengthy  52
# 2          775  2514                     173cm | 5'8'\nMostly Explosive  84
# 3          582  2400  180cm | 5'11"\nAvg & Lean(71kg)\nMostly Explosive  78
# 4        3,406  2415                 165cm | 5'4'\nControlled Explosive  64
# ..         ...   ...                                                ...  ..
# 255        238  1907         188cm | 6'2"\nTall & Stocky(90kg)\nLengthy  50
# 256        -28  2095      177cm | 5'10"\nAvg & Stocky(77kg)\nControlled  47
# 257        258  2290  181cm | 5'11"\nAvg & Normal(76kg)\nControlled ...  48
# 258     -1,001  2431       184cm | 6'0"\nAvg & Normal(89kg)\nControlled  46
# 259      3,318  2019                            165cm | 5'4'\nExplosive  64
#
#     Weight       Nation League         Club
# 0     70kg       Brazil  Icons  EA FC ICONS
# 1     77kg       France  Icons  EA FC ICONS
# 2     70kg       Brazil  Icons  EA FC ICONS
# 3     71kg  Netherlands  Icons  EA FC ICONS
# 4     70kg    Argentina  Icons  EA FC ICONS
# ..     ...          ...    ...          ...
# 255   90kg      England  Icons  EA FC ICONS
# 256   77kg        Italy  Icons  EA FC ICONS
# 257   76kg        Italy  Icons  EA FC ICONS
# 258   89kg      England  Icons  EA FC ICONS
# 259   70kg    Argentina  Icons  EA FC ICONS
#
# [260 rows x 22 columns]

# %%
icons.to_csv('Icons.csv', index=False)
